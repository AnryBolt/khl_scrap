# %%
import requests
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

# %% [markdown]
# Поместить драйвер в рабочую папку!
#
# Firefox driver:
# https://github.com/mozilla/geckodriver/releases
#
# Chrome driver:
# https://chromedriver.storage.googleapis.com/index.html

# %%
def get_html_with_selenium(url, name): # функция получения html страницы с имененм name и по адресу url
    options = webdriver.FirefoxOptions()
    options.set_preference("general.useragent.override", "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36")

    try:
        driver = webdriver.Firefox(options=options)
        driver.get(url=url)
        time.sleep(5)
    
        with open(name, "w", encoding='UTF-8') as file:
            file.write(driver.page_source)
    
    except Exception as ex:
        print(ex)
    finally:
        driver.close()
        driver.quit()

# %%
def get_table_khl(url, name): # Функция получения таблицы khl  с нужной страницы и пгенерация html страницы с этой таблицы именем "name.html"
    html_name = name + ".html"
    get_html_with_selenium(url, html_name)
    with open(html_name, encoding='UTF-8') as file:
        src = file.read()

    soup = BeautifulSoup(src, "lxml")
    sp = soup.find("table").\
        text.strip().\
            split("\n")

    sp = list(filter(lambda x: x.strip() != "", sp))

    n = 0
    sp2 = []
    for i in range(int(len(sp)/19)):
        sp2.append(sp[n :n + 19])
        n = n + 19
    df = pd.DataFrame(sp2[1:], columns=sp2[0])
    return df

# %%
sl = {# словарь определенных страниц khl
    "home" : "https://www.khl.ru/stat/teams/1217/home",\
      "road" : "https://www.khl.ru/stat/teams/1217/road"\
        }

# %% [markdown]
# Получение словаря таблиц khl

# %%
sl_tables = {}
for i in sl:
    sl_tables[i] = get_table_khl(sl[i], i)

# %%
home = sl_tables['home'].sort_values(['Ибз', 'ЗШ'], ascending = [True, False])
home.index = home['Клуб']
del home['Клуб']
home = home.astype(int)
home[home['Ибз'] <= 1]
# Out:
#                №   И   В  ВО  ВБ  ПБ  ПО   П   О  Ибз  Ибп  ЗШ   ПШ  Штр  \
# Клуб
# Динамо М      10  22  11   3   2   0   1   5  33    0    2  79   52  192
# Нефтехимик     7  25  10   3   1   3   4   4  35    0    4  65   63  196
# Спартак        8  22  14   3   0   0   0   5  34    1    0  93   66  166
# Металлург Мг   2  25  15   2   1   1   1   5  38    1    2  87   57  154
# Авангард       3  25  14   3   2   0   0   6  38    1    2  83   57  167
# СКА           13  23  12   2   1   0   1   7  31    1    2  77   49  242
# Ак Барс        1  25  13   5   1   0   1   5  39    1    3  74   50  186
# Трактор        9  25  13   3   0   0   1   8  33    1    1  67   49  159
# ХК Сочи       23  26   6   0   1   0   4  15  18    1    0  67  105  211
# Автомобилист   6  24  10   4   2   2   1   5  35    1    1  59   51  177
#
#               ШтрС  ОТБ  ПХТ  ПТР
# Клуб
# Динамо М       230   69  123  100
# Нефтехимик     233  100  128  122
# Спартак        262   62   70  156
# Металлург Мг   207   93  121  121
# Авангард       191   52  127  157
# СКА            231   62   82   98
# Ак Барс        162   83  111  162
# Трактор        220  129  203   95
# ХК Сочи        192  106   57   48
# Автомобилист   154  111  140  106
